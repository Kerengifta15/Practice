# %% [markdown]
# ### **Python loop pattern programming**
#
# **Print the below pattern**
#
# *\*\*\*\*
# *\*\*\*\*
# *\*\*\*\*
# *\*\*\*\*
# *\*\*\*\*

# %%
a = 1
while a <=5:   #row
    b = 1
    while b <= 5:   #column
        print("*", end="")
        b += 1
    a += 1
    print()
# Out:
# *****
# *****
# *****
# *****
# *****

# %%
row = int(input("Enter the number of rows: "))
column = int(input("Enter the number of columns: "))
symbol = input("Enter the symbol to be printed: ")
a = 1
while a <=row:   #row
    b = 1
    while b <= column:   #column
        print(symbol, end="")
        b += 1
    a += 1
    print()
# Out:
# #######
# #######
# #######
# #######
# #######

# %%
row = int(input("Enter the number of rows: "))
column = int(input("Enter the number of columns: "))
symbol = input("Enter the symbol: ")

for x in range(row):
    for y in range(column):
        print(symbol, end="")
    print()
# Out:
# %%%%%
# %%%%%
# %%%%%
# %%%%%
# %%%%%

# %%
#

#
##
###
####
#####

for x in range(5):
    for y in range(0,x+1):
        print("#", end="")
    print()
# Out:
# #
# ##
# ###
# ####
# #####

# %%
for x in range(5):
    for y in range(x+1):
        print("#", end="")
    print()
# Out:
# #
# ##
# ###
# ####
# #####

# %%
row = int(input("Enter the number of rows: "))
symbol = input("Enter the symbol: ")

for x in range(row):
    for y in range(x+1):
        print(symbol, end="")
    print()
# Out:
# #
# ##
# ###
# ####
# #####

# %%
row = int(input("Enter the number of rows: "))
symbol = input("Enter the symbol: ")

while n(row):
    while b(x+1):   #column
        print(symbol, end="")
        b += 1
    a += 1
    print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 row = int(input("Enter the number of rows: "))
#       2 symbol = input("Enter the symbol: ")
#       3
# ----> 4 while n(row):
#       5     while b(x+1):   #column
#       6         print(symbol, end="")
#       7         b += 1
#
# NameError: name 'n' is not defined

# %%
# 3rd pattern      #using string operator

for x in range(1,6):
    print("#" * x)
# Out:
# #
# ##
# ###
# ####
# #####
