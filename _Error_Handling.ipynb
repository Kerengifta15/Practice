# %% [markdown]
# ### **Exception Handling**

# %% [markdown]
# Types of error:
# 1. Syntax error
# 2. Logical error

# %%
# value error
# zero division error

# %%
num = input("Enter number: ")

mylist = list(map(int, num))

print(mylist)
# Out:
# [1, 2, 3, 4]

# %%
^[+][9][1][ ][6-9][0-9]{9}

^[+]91\s[6-9]\d{9}

# %%
Task
Date Formet
------------------
dd-/.mm-/.yyyy
1-31-/.1-12-/.2026
